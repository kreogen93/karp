# %%
import pandas as pd
import numpy as np
df = pd.read_csv('playstore.csv')
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.shape[0], df.shape[1]
# Out:
# (10840, 13)

# %% [markdown]
# **Описание данных**
# - App — название приложения
# - Category — категория, к которой относится приложение
# - Rating — рейтинг пользователей
# - Reviews — количество отзывов пользователей о приложении
# - Size — размер приложения
# - Installs — количество загрузок/установок приложения пользователями
# - Type — платное или бесплатное приложение
# - Price — цена приложения
# - Content Rating — возрастная группа, на которую ориентировано приложение
# - Genres — принадлежность приложения к нескольким жанрам
# - Last Updated — дата последнего обновления приложения в Play Store
# - Current Ver — текущая версия приложения в Play Store
# - Android Ver — минимальная требуемая версия Android

# %% [markdown]
# Какое количество уникальных приложений есть у нас в наших данных (колонка App).

# %%
len(df['App'].unique())
# Out:
# 9659

# %% [markdown]
# Для дальнейшего анализа нам необходимо убрать дубликаты приложений (колонка App) и сбросить индекс. Сохраните полученный результат в виде датафрейма в переменную unique_playstore

# %%
unique_playstore = df.copy()
unique_playstore['App'] = unique_playstore['App'].drop_duplicates()

# %%
unique_playstore = unique_playstore.set_index('App')

# %%
unique_playstore
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating  Reviews  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         4.1      159
# Coloring book moana                                    3.9      967
# U Launcher Lite – FREE Live Cool Themes, Hide Apps     4.7    87510
# Sketch - Draw & Paint                                  4.5   215644
# Pixel Draw - Number Art Coloring Book                  4.3      967
# ...                                                    ...      ...
# Sya9a Maroc - FR                                       4.5       38
# Fr. Mike Schmitz Audio Teachings                       5.0        4
# Parkinson Exercices FR                                 NaN        3
# The SCP Foundation DB fr nn5n                          4.5      114
# iHoroscope - 2018 Daily Horoscope & Astrology          4.5   398307
#
#                                                                   Size  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook                     19M
# Coloring book moana                                                14M
# U Launcher Lite – FREE Live Cool Themes, Hide Apps                8.7M
# Sketch - Draw & Paint                                              25M
# Pixel Draw - Number Art Coloring Book                             2.8M
# ...                                                                ...
# Sya9a Maroc - FR                                                   53M
# Fr. Mike Schmitz Audio Teachings                                  3.6M
# Parkinson Exercices FR                                            9.5M
# The SCP Foundation DB fr nn5n                       Varies with device
# iHoroscope - 2018 Daily Horoscope & Astrology                      19M
#
#                                                        Installs  Type Price  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook          10,000+  Free     0
# Coloring book moana                                    500,000+  Free     0
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   5,000,000+  Free     0
# Sketch - Draw & Paint                               50,000,000+  Free     0
# Pixel Draw - Number Art Coloring Book                  100,000+  Free     0
# ...                                                         ...   ...   ...
# Sya9a Maroc - FR                                         5,000+  Free     0
# Fr. Mike Schmitz Audio Teachings                           100+  Free     0
# Parkinson Exercices FR                                   1,000+  Free     0
# The SCP Foundation DB fr nn5n                            1,000+  Free     0
# iHoroscope - 2018 Daily Horoscope & Astrology       10,000,000+  Free     0
#
#                                                    Content Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           Everyone
# Coloring book moana                                      Everyone
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       Everyone
# Sketch - Draw & Paint                                        Teen
# Pixel Draw - Number Art Coloring Book                    Everyone
# ...                                                           ...
# Sya9a Maroc - FR                                         Everyone
# Fr. Mike Schmitz Audio Teachings                         Everyone
# Parkinson Exercices FR                                   Everyone
# The SCP Foundation DB fr nn5n                          Mature 17+
# iHoroscope - 2018 Daily Horoscope & Astrology            Everyone
#
#                                                                        Genres  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook                   Art & Design
# Coloring book moana                                 Art & Design;Pretend Play
# U Launcher Lite – FREE Live Cool Themes, Hide Apps               Art & Design
# Sketch - Draw & Paint                                            Art & Design
# Pixel Draw - Number Art Coloring Book                 Art & Design;Creativity
# ...                                                                       ...
# Sya9a Maroc - FR                                                    Education
# Fr. Mike Schmitz Audio Teachings                                    Education
# Parkinson Exercices FR                                                Medical
# The SCP Foundation DB fr nn5n                               Books & Reference
# iHoroscope - 2018 Daily Horoscope & Astrology                       Lifestyle
#
#                                                         Last Updated  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook       January 7, 2018
# Coloring book moana                                 January 15, 2018
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    August 1, 2018
# Sketch - Draw & Paint                                   June 8, 2018
# Pixel Draw - Number Art Coloring Book                  June 20, 2018
# ...                                                              ...
# Sya9a Maroc - FR                                       July 25, 2017
# Fr. Mike Schmitz Audio Teachings                        July 6, 2018
# Parkinson Exercices FR                              January 20, 2017
# The SCP Foundation DB fr nn5n                       January 19, 2015
# iHoroscope - 2018 Daily Horoscope & Astrology          July 25, 2018
#
#                                                            Current Ver  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook                   1.0.0
# Coloring book moana                                              2.0.0
# U Launcher Lite – FREE Live Cool Themes, Hide Apps               1.2.4
# Sketch - Draw & Paint                               Varies with device
# Pixel Draw - Number Art Coloring Book                              1.1
# ...                                                                ...
# Sya9a Maroc - FR                                                  1.48
# Fr. Mike Schmitz Audio Teachings                                   1.0
# Parkinson Exercices FR                                             1.0
# The SCP Foundation DB fr nn5n                       Varies with device
# iHoroscope - 2018 Daily Horoscope & Astrology       Varies with device
#
#                                                            Android Ver
# App
# Photo Editor & Candy Camera & Grid & ScrapBook            4.0.3 and up
# Coloring book moana                                       4.0.3 and up
# U Launcher Lite – FREE Live Cool Themes, Hide Apps        4.0.3 and up
# Sketch - Draw & Paint                                       4.2 and up
# Pixel Draw - Number Art Coloring Book                       4.4 and up
# ...                                                                ...
# Sya9a Maroc - FR                                            4.1 and up
# Fr. Mike Schmitz Audio Teachings                            4.1 and up
# Parkinson Exercices FR                                      2.2 and up
# The SCP Foundation DB fr nn5n                       Varies with device
# iHoroscope - 2018 Daily Horoscope & Astrology       Varies with device
#
# [10840 rows x 12 columns]

# %% [markdown]
# В этом задании названия колонок необходимо привести к стандартному виду — все буквы должны быть нижнего регистра, а пробелы должны быть заменены на нижние подчеркивания.

# %%
df = unique_playstore.copy()

# %%
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df
# Out:
#                                                                category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     rating  reviews  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook
.0.3 and up
# U Launcher Lite – FREE Live Cool Themes, Hide Apps        4.0.3 and up
# Sketch - Draw & Paint                                       4.2 and up
# Pixel Draw - Number Art Coloring Book                       4.4 and up
# ...                                                                ...
# Sya9a Maroc - FR                                            4.1 and up
# Fr. Mike Schmitz Audio Teachings                            4.1 and up
# Parkinson Exercices FR                                      2.2 and up
# The SCP Foundation DB fr nn5n                       Varies with device
# iHoroscope - 2018 Daily Horoscope & Astrology       Varies with device
#
# [10840 rows x 12 columns]

# %% [markdown]
# Давайте посмотрим на долю платных и бесплатных приложений.

# %%
df[df['type'] == 'Free'].shape[0] / df.shape[0]
# Out:
# 0.9261070110701107

# %%
df[df['type'] != 'Free'].shape[0] / df.shape[0]
# Out:
# 0.0738929889298893

# %% [markdown]
# Отберите из датафрейма только те приложения, которые относятся к образовательной категории  (EDUCATION) и с количеством отзывов пользователей более 1000.

# %%
df[(df['category'] == 'EDUCATION') & (df['reviews'] > 1000)]
# Out:
#                                                      category  rating  \
# App
# Duolingo: Learn Languages Free                      EDUCATION     4.7
# TED                                                 EDUCATION     4.6
# English Communication - Learn English for Chine...  EDUCATION     4.7
# Khan Academy                                        EDUCATION     4.6
# Learn English with Wlingua                          EDUCATION     4.7
# ...                                                       ...     ...
# SoloLearn: Learn to Code for Free                   EDUCATION     4.8
# Kids Learn Languages by Mondly                      EDUCATION     4.4
# Blinkist - Nonfiction Books                         EDUCATION     4.1
# Toca Life: City                                     EDUCATION     4.7
# Toca Life: Hospital                                 EDUCATION     4.7
#
#                                                     reviews  \
# App
# Duolingo: Learn Languages Free                      6289924
# TED                                                  181893
# English Communication - Learn English for Chine...     2544
# Khan Academy                                          85375
# Learn English with Wlingua                           314299
# ...                                                     ...
# SoloLearn: Learn to Code for Free                    256079
# Kids Learn Languages by Mondly                         2078
# Blinkist - Nonfiction Books                           16103
# Toca Life: City                                       31085
# Toca Life: Hospital                                    3528
#
#                                                                   size  \
# App
# Duolingo: Learn Languages Free                      Varies with device
# TED                                                                18M
# English Communication - Learn English for Chine...                 18M
# Khan Academy                                                       21M
# Learn English with Wlingua                                        3.3M
# ...                                                                ...
# SoloLearn: Learn to Code for Free                                 7.6M
# Kids Learn Languages by Mondly                      Varies with device
# Blinkist - Nonfiction Books                                        13M
# Toca Life: City                                                    24M
# Toca Life: Hospital                                                24M
#
#                                                         installs  type  price  \
# App
# Duolingo: Learn Languages Free                      100,000,000+  Free      0
# TED                                                  10,000,000+  Free      0
# English Communication - Learn English for Chine...      100,000+  Free      0
# Khan Academy                                          5,000,000+  Free      0
# Learn English with Wlingua                           10,000,000+  Free      0
# ...                                                          ...   ...    ...
# SoloLearn: Learn to Code for Free                     1,000,000+  Free      0
# Kids Learn Languages by Mondly                          100,000+  Free      0
# Blinkist - Nonfiction Books                           1,000,000+  Free      0
# Toca Life: City                                         500,000+  Paid  $3.99
# Toca Life: Hospital                                     100,000+  Paid  $3.99
#
#                                                    content_rating  \
# App
# Duolingo: Learn Languages Free                           Everyone
# TED                                                  Everyone 10+
# English Communication - Learn English for Chine...       Everyone
# Khan Academy                                             Everyone
# Learn English with Wlingua                               Everyone
# ...                                                           ...
# SoloLearn: Learn to Code for Free                            Teen
# Kids Learn Languages by Mondly                           Everyone
# Blinkist - Nonfiction Books                              Everyone
# Toca Life: City                                          Everyone
# Toca Life: Hospital                                      Everyone
#
#                                                                     genres  \
# App
# Duolingo: Learn Languages Free                         Education;Education
# TED                                                              Education
# English Communication - Learn English for Chine...               Education
# Khan Academy                                                     Education
# Learn English with Wlingua                                       Education
# ...                                                                    ...
# SoloLearn: Learn to Code for Free                                Education
# Kids Learn Languages by Mondly                         Education;Education
# Blinkist - Nonfiction Books                                      Education
# Toca Life: City                                     Education;Pretend Play
# Toca Life: Hospital                                 Education;Pretend Play
#
#                                                          last_updated  \
# App
# Duolingo: Learn Languages Free                         August 1, 2018
# TED                                                     July 27, 2018
# English Communication - Learn English for Chine...  December 29, 2017
# Khan Academy                                            July 27, 2018
# Learn English with Wlingua                                May 2, 2018
# ...                                                               ...
# SoloLearn: Learn to Code for Free                       July 12, 2018
# Kids Learn Languages by Mondly                      December 24, 2017
# Blinkist - Nonfiction Books                             July 31, 2018
# Toca Life: City                                          July 6, 2018
# Toca Life: Hospital                                     June 12, 2018
#
#                                                            current_ver  \
# App
# Duolingo: Learn Languages Free                      Varies with device
# TED                                                              3.2.5
# English Communication - Learn English for Chine...                 3.1
# Khan Academy                                                     5.0.0
# Learn English with Wlingua                                      1.94.9
# ...                                                                ...
# SoloLearn: Learn to Code for Free                                2.2.4
# Kids Learn Languages by Mondly                                   1.0.2
# Blinkist - Nonfiction Books                                      5.7.1
# Toca Life: City                                               1.5-play
# Toca Life: Hospital                                         1.1.1-play
#
#                                                            android_ver
# App
# Duolingo: Learn Languages Free                      Varies with device
# TED                                                         4.1 and up
# English Communication - Learn English for Chine...          4.0 and up
# Khan Academy                                                4.1 and up
# Learn English with Wlingua                                  4.0 and up
# ...                                                                ...
# SoloLearn: Learn to Code for Free                         4.0.3 and up
# Kids Learn Languages by Mondly                              4.1 and up
# Blinkist - Nonfiction Books                                 4.1 and up
# Toca Life: City                                             4.4 and up
# Toca Life: Hospital                                         4.4 and up
#
# [135 rows x 12 columns]

# %% [markdown]
# Трансформируйте данные о времени последнего обновления из датафрейма playstore (сохранен в ЛМС) в колонке last_updated в формат времени.

# %%
df['last_updated'] = pd.to_datetime(df['last_updated'])

# %% [markdown]
# Давайте уберем лишние символы из колонки с ценой (price), чтобы далее с ней было удобнее работать, и переведем данные в тип float.

# %%
df['price'].value_counts()
# Out:
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: price, Length: 92, dtype: int64

# %%
df['price'] = df['price'].apply(lambda x: x.replace('$', '')).astype(np.float64)

# %% [markdown]
# Рассчитаем медиану и среднее значение price и сохраним это в переменные price_median и price_mean, округлив значения до 2-х знаков после запятой

# %%
price_median = round(df['price'].median(), 2)
price_mean = round(df['price'].mean(), 2)
price_median, price_mean
# Out:
# (0.0, 1.03)
